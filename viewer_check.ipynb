# %% [markdown]
# # Phasing Coil Former – CadQuery Viewer
#
# Quick sanity check, then a full render of the parametric coil former.

# %%
import cadquery as cq
from jupyter_cadquery import show

# %%
# Quick sanity check – render a simple box
box = cq.Workplane("XY").box(10, 20, 30)
show(box)

# %% [markdown]
# ## Phasing Coil Former
#
# Import the full parametric model from `phasing_coil.py` and render it.

# %%
from phasing_coil import result as coil_former

show(coil_former)
